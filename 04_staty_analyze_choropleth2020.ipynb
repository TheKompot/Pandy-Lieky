# %% [markdown]
# # Analyza udajov podla krajin
#  * Ktore krajiny maju najvacsi podiel liekov na trhu?
#  * Z ktorych krajin su lieky najviac predavane?

# %%
! pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/d7/bf/e9cefb69d39155d122b6ddca53893b61535fa6ffdad70bf5ef708977f53f/geopandas-0.9.0-py2.py3-none-any.whl (994kB)
#      |████████████████████████████████| 1.0MB 5.2MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Collecting fiona>=1.8
#   Downloading https://files.pythonhosted.org/packages/ea/2a/404b22883298a3efe9c6ef8d67acbf2c38443fa366ee9cd4cd34e17626ea/Fiona-1.8.19-cp37-cp37m-manylinux1_x86_64.whl (15.3MB)
#      |████████████████████████████████| 15.3MB 274kB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/b1/72/d52e9ca81caef056062d71991b0e9b1d16af042245627c5d0e4916a36c4f/pyproj-3.0.1-cp37-cp37m-manylinux2010_x86_64.whl (6.5MB)
#      |████████████████████████████████| 6.5MB 38.4MB/s
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (1.19.5)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Installing collected packages: munch, cligj, click-plugins, fiona, pyproj, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.19 geopandas-0.9.0 munch-2.5.0 pyproj-3.0.1

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px
import geopandas

# %% [markdown]
# ## Z ktorych krajin su lieky najviac predavane?

# %%
krajiny = ['Slovakia', 'Czech Republic', 'Germany', 'Netherlands', 'Slovenia',
           'France', 'Ireland', 'Hungary', 'Italy', 'Austria', 'Poland', 'Belgium',
           'Cyprus', 'Iceland', 'Denmark', 'Portugal', 'Luxembourg', 'Sweden',
           'Finland', 'Spain', 'Bulgaria', 'Latvia', 'Norway', 'Croatia', 'United Kingdom',
           'Greece', 'Switzerland', 'Lithuania', 'Malta', 'Monaco', 'Turkey']
pocet_bal = [2.656218e+07,1.976097e+07,1.375259e+07,1.218893e+07,8.495347e+06,
             5.313075e+06,4.602191e+06,4.369214e+06,3.118190e+06,1.773538e+06,1.991132e+06,8.622657e+05,
             1.138812e+06,1.111589e+06,9.474987e+05,4.703990e+05,7.149877e+05,5.019233e+05,
             3.865638e+05,2.772255e+05,7.883036e+04,6.260930e+04,9.711686e+03,8.663000e+03,4.299100e+03,
             8.590000e+02,7.296000e+02,7.200000e+01,1.310000e+02,3.000000e+00,1.000000e+00]

table2020 = pd.DataFrame(list(zip(krajiny, pocet_bal)),
               columns =['NAME', 'Počet balení']).set_index('NAME').sort_index()
url = 'https://raw.githubusercontent.com/leakyMirror/map-of-europe/master/GeoJSON/europe.geojson'
staty = geopandas.read_file(url).set_index('NAME')
staty['Počet balení'] = [0 for i in range(len(staty))]

for i in range(len(krajiny)):
  staty.loc[krajiny[i],['Počet balení']] = pocet_bal[i]
display(staty.head())
# Out:
#                         FID  ... Počet balení
# NAME                         ...
# Azerbaijan              0.0  ...         0.00
# Albania                 0.0  ...         0.00
# Armenia                 0.0  ...         0.00
# Bosnia and Herzegovina  0.0  ...         0.00
# Bulgaria                0.0  ...     78830.36
#
# [5 rows x 13 columns]

# %%
fig, ax = plt.subplots(1,figsize=(15,15))
staty.plot(column='Počet balení', legend=True, ax=ax,
           cmap='viridis_r', edgecolor='white', 
           legend_kwds={'shrink': 0.6});
ax.axis('off')
ax.set_title('Krajiny - závislosť od počtu predaných balení (2020)', fontdict={'fontsize': '20', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Krajiny - závislosť od počtu predaných balení (2020)')

# %%
krajiny = ['Slovakia', 'Czech Republic', 'Germany', 'Netherlands', 'Slovenia',
           'France', 'Ireland', 'Hungary', 'Italy', 'Austria', 'Poland', 'Belgium',
           'Cyprus', 'Iceland', 'Denmark', 'Portugal', 'Luxembourg', 'Sweden',
           'Finland', 'Spain', 'Bulgaria', 'Latvia', 'Norway', 'Croatia', 'United Kingdom',
           'Greece', 'Switzerland', 'Lithuania', 'Malta', 'Monaco', 'Turkey']
pocet_liekov = [3014, 3512, 3771,1307,2090,
                3049,1194,853,269,954,784,662,
                447,483,304,86,113,326,
                315,277,30,62,58,27,163,
                55,34,14,11,2,1]

staty['Počet liekov'] = [0 for i in range(len(staty))]

for i in range(len(krajiny)):
  staty.loc[krajiny[i],['Počet liekov']] = pocet_liekov[i]
display(staty.head())
# Out:
#                         FID FIPS  ... Počet balení Počet liekov
# NAME                              ...
# Azerbaijan              0.0   AJ  ...         0.00            0
# Albania                 0.0   AL  ...         0.00            0
# Armenia                 0.0   AM  ...         0.00            0
# Bosnia and Herzegovina  0.0   BK  ...         0.00            0
# Bulgaria                0.0   BU  ...     78830.36           30
#
# [5 rows x 14 columns]

# %%
fig, ax = plt.subplots(1,figsize=(15,15))
staty.plot(column='Počet liekov', figsize=(15,15), legend=True, 
           cmap='viridis_r',edgecolor='white', ax=ax,
           legend_kwds={'shrink': 0.6});
ax.axis('off')
ax.set_title('Krajiny - závislosť od počtu liekov na trhu (2020)', fontdict={'fontsize': '20', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Krajiny - závislosť od počtu liekov na trhu (2020)')
